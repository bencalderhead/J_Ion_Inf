# %%
projbasedir = "/home/michaelepstein/Ion/";

# %%
cd(projbasedir)
output_samples = "/Output/ION_Ball_MH_Output_Final"
using MAT
using Distributions
using MCMCTypes
using PyPlot
using StatsBase

# %%
# Function for updating parameters - Gibbs step 1
include(string(projbasedir,"MCMCUpdateParameters.jl"))

# Function for updating indicator - Gibbs step 2
include(string(projbasedir,"MCMCUpdateIndicator.jl"))

# Function for the main MCMC routine
include(string(projbasedir,"MCMCRun.jl"))

# Enum of Ion-channel models which can be created
AvailableModels = include(string(projbasedir,"ion/model/ModelEnum.jl"))

# Function to create available models
include(string(projbasedir,"ion/model/CreateModel.jl"))

# Function to parse matlab data files
include(string(projbasedir,"ion/data/MatlabParser.jl"))

Sampler             = "MH"
OutputID            = "Output/ION_Ball_MH_Output"
InitialStepSize     = 1 # MH stepsize
NumOfIterations     = 1000

NumOfProposals      = 5
ProposalCovariance  = [ 100 0.0; 0.0 10^8 ]
InitialiseFromPrior = false # Sample starting parameters from prior

# Define function for updating the parameters (1st Gibbs step)
UpdateParasFunction     = UpdateParameters

# Define function for sampling the indicator variable (2nd Gibbs step)
SampleIndicatorFunction = SampleIndicator

#create the Ball model
println("Creating model BALL 1989")
model = CreateModel(AvailableModels.BALL1989)

#data parsing from MATLAB experimental files

datafile = string(projbasedir,"ion/data/balldata.mat")
println("Parsing datafile $datafile")
data = MatlabParser(datafile)

println(string("Likelihood with default params = ", model.LLEval(model.DefaultParas,model,data)))

MySimulation = MCMCSimulation( OutputID,
                               Sampler,
                               NumOfProposals,
                               NumOfIterations,
                               InitialStepSize,
                               ProposalCovariance,
                               InitialiseFromPrior,
                               UpdateParasFunction,
                               SampleIndicatorFunction,
                               model,
                               data)


# Run the MCMC code, passing in the MCMCSimulation object
MCMCRun( MySimulation );
println("done")
# Out:
# Creating model BALL 1989
# Creating Ball 1989 Model. Params = 2, States = 2
# Parsing datafile /home/michaelepstein/Ion/ion/data/balldata.mat
# Likelihood with default params = 74892.11410304286
# Setting up Markov chain proposal...
# Creating chain object...
# Initialising...
# The chosen sampler is Metropolis-Hastings.
# Starting main MCMC routine...
# 100
# LL = 84353.1302873139
# Param values 487.1923736892371,4.899711167850878e6
# 0.1919191919191919
# Local Acceptance Rate = 0.1919191919191919
# 200
# LL = 85736.44415036247
# Param values 811.1336638670115,4.891873719172923e6
# 0.19597989949748743
# Local Acceptance Rate = 0.2
# 300
# LL = 86071.94417140272
# Param values 924.2645403563785,5.187968874362451e6
# 0.21070234113712374
# Local Acceptance Rate = 0.24
# 400
# LL = 86299.72215543778
# Param values 985.3033034132887,5.506064951843854e6
# 0.22807017543859648
# Local Acceptance Rate = 0.28
# 500
# LL = 86521.15819471722
# Param values 993.7010840014907,5.867910500376065e6
# 0.25851703406813625
# Local Acceptance Rate = 0.38
# 600
# LL = 86651.20144755977
# Param values 981.8748876045426,6.1025838126706425e6
# 0.27545909849749584
# Local Acceptance Rate = 0.36
# 700
# LL = 86804.86598074841
# Param values 967.1770522020043,6.418583414770541e6
# 0.2861230329041488
# Local Acceptance Rate = 0.35
# 800
# LL = 86917.47171902556
# Param values 972.5072569958804,6.682775556202695e6
# 0.29912390488110135
# Local Acceptance Rate = 0.39
# 900
# LL = 87049.57218657096
# Param values 992.6643073526926,7.043214722188227e6
# 0.3014460511679644
# Local Acceptance Rate = 0.32
# 1000
# LL = 87143.33481178213
# Param values 987.5846111674479,7.3378507519503385e6
# 0.3103103103103103
# Local Acceptance Rate = 0.39
# 1100
# LL = 87224.47135751296
# Param values 999.6610528050059,7.641872026700912e6
# 0.32666060054595086
# Local Acceptance Rate = 0.49
# 1200
# LL = 87287.61238487066
# Param values 983.5855132389206,7.910545479846222e6
# 0.33611342785654713
# Local Acceptance Rate = 0.44
# 1300
# LL = 87338.928349574
# Param values 1006.1855846817389,8.181592850789853e6
# 0.3433410315627406
# Local Acceptance Rate = 0.43
# 1400
# LL = 87379.2998692225
# Param values 977.1089737296725,8.422440828099089e6
# 0.3588277340957827
# Local Acceptance Rate = 0.56
# Increasing StepSize to 1.1
#
# 1500
# LL = 87414.59033382866
# Param values 983.4327478307164,8.681260534284199e6
# 0.3802535023348899
# Local Acceptance Rate = 0.68
# Increasing StepSize to 1.2100000000000002
#
# 1600
# LL = 87439.92144079907
# Param values 1003.0114793233989,8.91588848496425e6
# 0.3908692933083177
# Local Acceptance Rate = 0.55
# Increasing StepSize to 1.3310000000000004
#
# 1700
# LL = 87466.2721245117
# Param values 986.0067585257987,9.249211737429885e6
# 0.3972925250147145
# Local Acceptance Rate = 0.5
# 1800
# LL = 87474.6482925817
# Param values 1012.6089085625883,9.405872532681243e6
# 0.41411895497498613
# Local Acceptance Rate = 0.7
# Increasing StepSize to 1.4641000000000006
#
# 1900
# LL = 87480.33262316986
# Param values 1000.7689055610014,9.517994660851663e6
# 0.43233280674038965
# Local Acceptance Rate = 0.76
# Increasing StepSize to 1.6105100000000008
#
# 2000
# LL = 87484.00911584625
# Param values 992.8419649680112,9.636227945088249e6
# 0.4432216108054027
# Local Acceptance Rate = 0.65
# Increasing StepSize to 1.771561000000001
#
# 2100
# LL = 87485.96661024733
# Param values 999.4335389533645,9.706686437102731e6
# 0.4573606479275846
# Local Acceptance Rate = 0.74
# Increasing StepSize to 1.9487171000000014
#
# 2200
# LL = 87487.72740629273
# Param values 1007.5796141784095,9.81819560510658e6
# 0.47203274215552526
# Local Acceptance Rate = 0.78
# Increasing StepSize to 2.1435888100000016
#
# 2300
# LL = 87488.16071667298
# Param values 1014.8533710917408,9.943804687470257e6
# 0.48325358851674644
# Local Acceptance Rate = 0.73
# Increasing StepSize to 2.357947691000002
#
# 2400
# LL = 87487.71481256907
# Param values 1016.6976604426965,9.889619487969207e6
# 0.49145477282200917
# Local Acceptance Rate = 0.68
# Increasing StepSize to 2.5937424601000023
#
# 2500
# LL = 87488.69002608398
# Param values 1003.199360491888,9.987561522179445e6
# 0.5014005602240896
# 2600
# LL = 87487.08397770443
# Param values 1023.6495816862846,9.961533211861687e6
# 0.510965756060023
# 2700
# LL = 87488.32965958035
# Param values 1001.0406517626845,9.867086916245999e6
# 0.5190811411633939
# 2800
# LL = 87485.59386356338
# Param values 1011.0593282597719,9.707700151271306e6
# 0.5262593783494105
# 2900
# LL = 87486.36810931246
# Param values 999.1958144986854,9.726339951696627e6
# 0.5315626077957917
# 3000
# LL = 87488.36670272247
# Param values 994.5602482225361,9.983778424151432e6
# 0.5401800600200066
# 3100
# LL = 87486.30936642957
# Param values 979.5706300981545,9.990159202102501e6
# 0.5485640529202969
# 3200
# LL = 87488.4977585611
# Param values 1010.6936713239119,9.98231929440802e6
# 0.554548296342607
# 3300
# LL = 87485.65621325756
# Param values 1022.2818279050829,9.78106927758944e6
# 0.55835101545923
# 3400
# LL = 87488.37825551051
# Param values 1004.7360602821321,9.874776124385376e6
# 0.5625183877611062
# 3500
# LL = 87488.54981297845
# Param values 1003.2371095141079,9.899303639008893e6
# 0.5681623320948842
# 3600
# LL = 87488.29901608816
# Param values 993.9558230693874,9.916707904288184e6
# 0.5712697971658794
# 3700
# LL = 87488.60798146637
# Param values 1001.8435105808859,9.912584195235863e6
# 0.5720464990537983
# 3800
# LL = 87488.35281264408
# Param values 1002.3971800674012,9.868928887092631e6
# 0.5777836272703343
# 3900
# LL = 87486.9345670524
# Param values 982.8366797470778,9.903851115094077e6
# 0.5811746601692742
# 4000
# LL = 87487.60581849165
# Param values 1019.361961923918,9.92725861435636e6
# 0.5828957239309828
# 4100
# LL = 87488.35696775482
# Param values 1009.7805047758517,9.899557008916246e6
# 0.5872163942424982
# 4200
# LL = 87488.67113752879
# Param values 1001.5804899374997,9.933348985707805e6
# 0.5887115979995237
# 4300
# LL = 87488.64932170512
# Param values 1003.4937304569438,9.922634724615607e6
# 0.591300302395906
# 4400
# LL = 87487.51471401993
# Param values 987.2008045981884,9.889915426362243e6
# 0.5942259604455558
# 4500
# LL = 87487.77513208472
# Param values 990.6792389677643,1.0034719616236046e7
# 0.5961324738830851
# 4600
# LL = 87487.33345684718
# Param values 993.4027188713922,1.0108073695326906e7
# 0.5983909545553381
# 4700
# LL = 87487.14063921817
# Param values 999.3054446481603,1.0150871799098197e7
# 0.6011917429240264
# 4800
# LL = 87488.60258655493
# Param values 1008.7352905059462,9.964451156596456e6
# 0.6055428214211294
# 4900
# LL = 87481.08346370091
# Param values 969.0328012609106,1.0193007801596621e7
# 0.6076750357215759
# 5000
# LL = 87488.00282935923
# Param values 996.1662200987657,1.006662458459356e7
# 0.6099219843968794
#
# Parameter 1 Mean: 973.5840374999505
# Parameter 1 Var: 12417.972499643487
# Parameter 1 Std: 111.4359569422881
#
# Parameter 2 Mean: 8.863407733842615e6
# Parameter 2 Var: 2.7076436954911304e12
# Parameter 2 Std: 1.6454919311534562e6
# done

# %%
readdir("Output")
# Out:
# 57-element Array{Union(ASCIIString,UTF8String),1}:
#  ".gitignore"
#  "ION_Ball_AdaptiveMH_Output_LL_Part1.0"
#  "ION_Ball_AdaptiveMH_Output_LL_Part_Final"
#  "ION_Ball_AdaptiveMH_Output_Part1.0"
#  "ION_Ball_AdaptiveMH_Output_Part_Final"
#  "ION_Ball_MH_Output_AcceptanceLocal_Part1.0"
#  "ION_Ball_MH_Output_AcceptanceLocal_Part_Final"
#  "ION_Ball_MH_Output_Acceptance_Part1.0"
#  "ION_Ball_MH_Output_Acceptance_Part_Final"
#  "ION_Ball_MH_Output_LL_Part1.0"
#  "ION_Ball_MH_Output_LL_Part_Final"
#  "ION_Ball_MH_Output_Part1.0"
#  "ION_Ball_MH_Output_Part_Final"
#  ⋮
#  "ION_dCK_MultMH_Output_LL_Part1.0"
#  "ION_dCK_MultMH_Output_LL_Part_Final"
#  "ION_dCK_MultMH_Output_Part1.0"
#  "ION_dCK_MultMH_Output_Part_Final"
#  "ION_SevenState_MultMH_MWG_Output_AcceptanceLocal_Part1.0"
#  "ION_SevenState_MultMH_MWG_Output_AcceptanceLocal_Part_Final"
#  "ION_SevenState_MultMH_MWG_Output_Acceptance_Part1.0"
#  "ION_SevenState_MultMH_MWG_Output_Acceptance_Part_Final"
#  "ION_SevenState_MultMH_MWG_Output_LL_Part1.0"
#  "ION_SevenState_MultMH_MWG_Output_LL_Part_Final"
#  "ION_SevenState_MultMH_MWG_Output_Part1.0"
#  "ION_SevenState_MultMH_MWG_Output_Part_Final"

# %%
samples = readdlm("Output/ION_Ball_MH_Output_Part_Final",',')
# Out:
# 2x5000 Array{Float64,2}:
#  104.412      104.412      104.412      …  996.166      996.166
#    4.99311e6    4.99311e6    4.99311e6       1.00666e7    1.00666e7

# %%
for i in (1)
    for j in (1,2)
        iterator=2*(i-1)+j
        subplot(2,2,iterator)
        plt.plot(vec(samples[iterator,:]))
        plt.title(model.ParaNames[iterator])
        
        plt.show()
    end
end
plt.suptitle("Trace plots")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fe1da417750>)
# PyObject <matplotlib.text.Text object at 0x7fe1d9a3a490>

# %%
#parameter histograms and scatter
ASSUME_BURNIN = floor(length(vec(samples[1,:]))/2)
println("Assuming burnin of ",ASSUME_BURNIN)
for i in (1)
    for j in (1,2)
        iterator=2*(i-1)+j
        subplot(2,2,iterator)
        plt.hist(vec(samples[iterator,ASSUME_BURNIN:end]))
        plt.title(model.ParaNames[iterator])
        
        plt.show()
    end
end
plt.suptitle("Parameter Histograms")
# Out:
# Assuming burnin of 25
# 00.0
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fe1d9b9ab10>)
# PyObject <matplotlib.text.Text object at 0x7fe1d97fe610>

# %%
figure(figsize=(4,4))
plt.scatter(vec(samples[1,ASSUME_BURNIN:end]),vec(samples[2,ASSUME_BURNIN:end]),s=0.5, alpha=0.5)
plt.xlabel(model.ParaNames[1])
plt.ylabel(model.ParaNames[2])
plt.title("Parameter scatterplot")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fe1d971e2d0>)
# PyObject <matplotlib.text.Text object at 0x7fe1d966fd10>

# %%
LAGS=50
println("Assuming burnin of ",ASSUME_BURNIN, " and LAGS of ", LAGS)
for i in (1)
    for j in (1,2)
        iterator=2*(i-1)+j
        subplot(2,2,iterator)
        plt.plot(autocor(vec(samples[iterator,ASSUME_BURNIN:end]),0:LAGS))
        plt.title(model.ParaNames[iterator])
        
        plt.show()
    end
end
plt.suptitle("Parameter Autocorrelations")
# Out:
# Assuming burnin of 25
# 00.0 and LAGS of 50
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fe1d9778910>)
# PyObject <matplotlib.text.Text object at 0x7fe1d95eded0>

# %%
LL = readdlm("Output/ION_Ball_MH_Output_LL_Part_Final",',');

# %%
figure(figsize=(5, 3))
plot(LL)
ylabel("Log-likelihood")
xlabel("Iteration")
title("Log-likelihood convergence")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fe1d95edf50>)
# PyObject <matplotlib.text.Text object at 0x7fe1d947a450>

# %%
acceptance = readdlm("Output/ION_Ball_MH_Output_Acceptance_Part_Final",',');
sizes = size(acceptance)
plot([1:sizes[1]],acceptance[:])
acceptancelocal = readdlm("Output/ION_Ball_MH_Output_AcceptanceLocal_Part_Final",',');
plot([1:sizes[1]],acceptancelocal[:])
ylabel("acceptance rate")
xlabel("Iteration*100")
title("Acceptance rate")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fe1d93c4290>)
# PyObject <matplotlib.text.Text object at 0x7fe1d9366790>
